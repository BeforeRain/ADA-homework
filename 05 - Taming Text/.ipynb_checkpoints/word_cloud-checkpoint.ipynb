# %% [markdown]
# # Library learn:
#
# ## Word could

# %%
from os import path
from wordcloud import WordCloud

d = path.dirname('E:/2016-2017fall/ada/Homework_sissy/05 - Taming Text/')

# Read the whole text.
text = open(path.join(d, 'constitution.txt')).read()

# %%
# Generate a word cloud image
wordcloud = WordCloud().generate(text)

# Display the generated image:
# the matplotlib way:
import matplotlib.pyplot as plt
plt.imshow(wordcloud)
plt.axis("off")

# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
#image = wordcloud.to_image()
#image.show()

# %%
# lower max_font_size
wordcloud = WordCloud(max_font_size=40).generate(text)
plt.figure()
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# The pil way (if you don't have matplotlib)
#image = wordcloud.to_image()
#image.show()

# %% [markdown]
# ## nltk
# ### start with guidance http://textminingonline.com/dive-into-nltk-part-i-getting-started-with-nltk

# %%
import nltk

# %%
from nltk import sent_tokenize, word_tokenize, pos_tag

# %%
text = "Machine learning is the science of getting computers to act without being explicitly programmed. In the past decade, machine learning has given us self-driving cars, practical speech recognition, effective web search, and a vastly improved understanding of the human genome. Machine learning is so pervasive today that you probably use it dozens of times a day without knowing it. Many researchers also think it is the best way to make progress towards human-level AI. In this class, you will learn about the most effective machine learning techniques, and gain practice implementing them and getting them to work for yourself. More importantly, you'll learn about not only the theoretical underpinnings of learning, but also gain the practical know-how needed to quickly and powerfully apply these techniques to new problems. Finally, you'll learn about some of Silicon Valley's best practices in innovation as it pertains to machine learning and AI."

# %%
sents = sent_tokenize(text)
# cut into sentences

# %%
tokens = word_tokenize(text)
# cut into words

# %%
tagged_tokens = pos_tag(tokens)
# words with tags -- types of words
import matplotlib.pyplot as plt
t1=', '.join(map(str, tokens))
t2=', '.join(map(str, tagged_tokens))
word_tokens = WordCloud(max_font_size=40).generate(t1)
plt.imshow(word_tokens)
plt.axis("off")

# lower max_font_size
word_tag = WordCloud(max_font_size=40).generate(t2)
plt.figure()
plt.imshow(word_tag)
plt.axis("off")
plt.show()

# %% [markdown]
# ### Tokenization

# %%
from nltk import word_tokenize
raw="This is my first test sentence"
tokens = word_tokenize(raw)
tokens
# Out:
# ['This', 'is', 'my', 'first', 'test', 'sentence']

# %%
text = nltk.Text(tokens)
type(text)
text[:3]
# Out:
# ['This', 'is', 'my']

# %%
raw.find('first')
# Out:
# 11

# %%
raw[11]
# Out:
# 'f'

# %%
import pandas as pd
import numpy as np

# %%
raw=pd.read_csv("Emails.csv")
raw.shape
# Out:
# (7945, 22)

# %%
raw.ix[:5,:11]
# Out:
#    Id  DocNumber                                    MetadataSubject  \
# 0   1  C05739545                                                WOW
# 1   2  C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 2   3  C05739547                                      CHRIS STEVENS
# 3   4  C05739550                         CAIRO CONDEMNATION - FINAL
# 4   5  C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 5   6  C05739559  MEET THE RIGHT-WING EXTREMIST BEHIND ANTI-MUSL...
#
#           MetadataTo       MetadataFrom  SenderPersonId  \
# 0                  H  Sullivan, Jacob J            87.0
# 1                  H                NaN             NaN
# 2                 ;H    Mills, Cheryl D            32.0
# 3                  H    Mills, Cheryl D            32.0
# 4       Abedin, Huma                  H            80.0
# 5  Russorv@state.gov                  H            80.0
#
#             MetadataDateSent       MetadataDateReleased  \
# ...

# %%
raw.ix[:5,11:]
# Out:
#                                     ExtractedSubject ExtractedTo  \
# 0                                            FW: Wow         NaN
# 1                                                NaN         NaN
# 2                                  Re: Chris Stevens          B6
# 3                    FVV: Cairo Condemnation - Final         NaN
# 4                                                NaN         NaN
# 5  Meet The Right Wing Extremist Behind Anti-Musl...         NaN
#
#                               ExtractedFrom         ExtractedCc  \
# 0  Sullivan, Jacob J <Sullivan11@state.gov>                 NaN
# 1                                       NaN                 NaN
# 2       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 3       Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 4                                       NaN                 NaN
# 5                                       NaN                 NaN
#
# ...

# %%
text=raw['ExtractedSubject']+raw['ExtractedBodyText']
text=text.dropna()
text.ix[:5]
# Out:
# 2                                 Re: Chris StevensThx
# 5    Meet The Right Wing Extremist Behind Anti-Musl...
# dtype: object

# %%
reduce_list=['Re:','Fw:','U.S. Department of State','Case No.','Doc No.','STATE DEPT.','FVV:','Fwd:']
for word in reduce_list:
    print(word)
# Out:
# Re:
# Fw:
# U.S. Department of State
# Case No.
# Doc No.
# STATE DEPT.
# FVV:
# Fwd:

# %%
for line in text:
    count=0
    for word in reduce_list:
        if(line.startswith(word)):
            #print(line)
            count=1
            break
    if(count==0):
        print(line)
# Out:
# Meet The Right Wing Extremist Behind Anti-Muslim Film That Sparked Deadly RiotsPis print.
# -•-...-^
# H < hrod17@clintonernailcom>
# Wednesday, September 12, 2012 2:11 PM
# °Russorv@state.gov'
# Fw: Meet The Right-Wing Extremist Behind Anti-fvluslim Film That Sparked Deadly Riots
# From [meat)
# Sent: Wednesday, September 12, 2012 01:00 PM
# To: 11
# Subject: Meet The Right Wing Extremist Behind Anti-Muslim Film That Sparked Deadly Riots
# htte/maxbiumenthal.com12012/09/meet-the-right-wing-extremist-behind-anti-musiim-tihn-that-sparked-
# deadly-riots/
# Sent from my Verizon Wireless 4G LTE DROID
# U.S. Department of State
# Case No. F-2015-04841
# Doc No. C05739559
# Date: 05/13/2015
# STATE DEPT. - PRODUCED TO HOUSE SELECT BENGHAZI COMM.
# SUBJECT TO AGREEMENT ON SENSITIVE INFORMATION & REDACTIONS. NO FOIA WAIVER. STATE-5CB0045251
# more on LibyaB6
# Wednesday, September 12, 2012 6:16 PM
# Fwd: more on libya
# Libya 37 sept 12 12.docx
# Sending direct. Just in.
# ...

# %%
import nltk
from nltk.corpus import stopwords
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers',
#  'herself',
#  'it',
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
# ...

# %%
def content_fraction(text):
    stopwords = nltk.corpus.stopwords.words('english')
    content = [w for w in text if w.lower() not in stopwords]
    return len(content) / len(text)

# %%
content_fraction(text)
# Out:
# 1.0

# %%
text_=raw['RawText']

# %%
#from bs4 import BeautifulSoup
text_str=text.to_string()
#text_utf=BeautifulSoup(text_str,"lxml").get_text()
tokens = word_tokenize(text_str)
#tokens = word_tokenize(text_utf)
tokens
# Out:
# ['2',
#  'Re',
#  ':',
#  'Chris',
#  'StevensThx',
#  '5',
#  'Meet',
#  'The',
#  'Right',
#  'Wing',
#  'Extremist',
#  'Behind',
#  'Anti-Musl',
#  '...',
#  '8',
#  'FVV',
#  ':',
#  'Secretary',
#  "'s",
#  'remarksFYI',
#  '9',
#  'more',
#  'on',
#  'LibyaB6\\nWednesday',
#  ',',
#  'September',
#  '12',
#  ',',
#  '2012',
#  '...',
#  '10',
#  'AbZ',
#  'and',
#  'Hb3',
#  'on',
#  'Libya',
#  'and',
#  'West',
#  'Bank/GazaFyi\\nB6',
#  '...',
#  '12',
#  'heyFyi',
#  '14',
#  'RE',
#  ':',
#  'Not',
#  'a',
#  'dry',
#  'eye',
#  'in',
#  'NEA_',
#  '...',
#  '..\\nFrom',
#  'Randolph',
#  '...',
#  '16',
#  'Fw',
#  ':',
#  'The',
#  'Youth',
#  'of',
#  'LibyaHope',
#  '.',
#  'See',
#  'picture',
#  'below',
#  '...',
#  '17',
#  'Fw',
#  ':',
#  'One',
#  'More',
#  'PhotoAnother',
#  'photo',
#  '.',
#  '18',
#  'Fw',
#  ':',
#  'S',
#  'todayThis',
#  'is',
#  'nice',
#  '.',
#  '20',
#  'Fwd',
#  ':',
#  'more',
#  'on',
#  'libyaH',
#  '<',
#  'hrod17',
#  '@',
# ...
