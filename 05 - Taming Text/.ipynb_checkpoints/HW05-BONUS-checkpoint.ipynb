# %% [markdown]
# # HW 05 - Taming Text
#
# ## BONUS
#
# ### Build the communication graph (unweighted and undirected) among the different email senders and recipients using the `NetworkX` library. Find communities in this graph with `community.best_partition(G)` method from the community detection module. Print the most frequent 20 words used by the email authors of each community. Do these word lists look similar to what you've produced at step 3 with LDA? Can you identify clear discussion topics for each community? Discuss briefly the obtained results.

# %% [markdown]
# First we import the necessary modules.

# %%
import community
import networkx as nx

# %% [markdown]
# ### Simple example

# %% [markdown]
# Let's try the example from http://perso.crans.org/aynaud/communities/index.html:

# %%
import matplotlib.pyplot as plt

#better with karate_graph() as defined in networkx example.
#erdos renyi don't have true community structure
G = nx.erdos_renyi_graph(30, 0.05)

#first compute the best partition
partition = community.best_partition(G)

#drawing
size = float(len(set(partition.values())))
pos = nx.spring_layout(G)
count = 0.
for com in set(partition.values()) :
    count = count + 1.
    list_nodes = [nodes for nodes in partition.keys()
                                if partition[nodes] == com]
    nx.draw_networkx_nodes(G, pos, list_nodes, node_size = 20,
                                node_color = str(count / size))


nx.draw_networkx_edges(G,pos, alpha=0.5)
plt.show()

# %% [markdown]
# ### Scouting useful info from the emails corpus

# %%
import pandas as pd

emails = pd.read_csv('hillary-clinton-emails/Emails.csv')
emails.set_index(["Id"], drop=True, inplace=True)
print(emails.shape)
emails.ix[:5,:11]
# Out:
# (7945, 21)
#     DocNumber                                    MetadataSubject  \
# Id
# 1   C05739545                                                WOW
# 2   C05739546  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
# 3   C05739547                                      CHRIS STEVENS
# 4   C05739550                         CAIRO CONDEMNATION - FINAL
# 5   C05739554  H: LATEST: HOW SYRIA IS AIDING QADDAFI AND MOR...
#
#       MetadataTo       MetadataFrom  SenderPersonId  \
# Id
# 1              H  Sullivan, Jacob J            87.0
# 2              H                NaN             NaN
# 3             ;H    Mills, Cheryl D            32.0
# 4              H    Mills, Cheryl D            32.0
# 5   Abedin, Huma                  H            80.0
#
#              MetadataDateSent       MetadataDateReleased  \
# Id
# 1   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 2   2011-03-03T05:00:00+00:00  2015-05-22T04:00:00+00:00
# 3   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 4   2012-09-12T04:00:00+00:00  2015-05-22T04:00:00+00:00
# 5   2011-03-11T05:00:00+00:00  2015-05-22T04:00:00+00:00
#
#                                       MetadataPdfLink MetadataCaseNumber  \
# Id
# 1   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739545...       F-2015-04841
# 2   DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739546...       F-2015-04841
# 3   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739547...       F-2015-04841
# 4   DOCUMENTS/HRC_Email_1_296/HRCH2/DOC_0C05739550...       F-2015-04841
# 5   DOCUMENTS/HRC_Email_1_296/HRCH1/DOC_0C05739554...       F-2015-04841
#
#    MetadataDocumentClass                 ExtractedSubject
# Id
# 1          HRC_Email_296                          FW: Wow
# 2          HRC_Email_296                              NaN
# 3          HRC_Email_296                Re: Chris Stevens
# 4          HRC_Email_296  FVV: Cairo Condemnation - Final
# 5          HRC_Email_296                              NaN

# %%
emails.ix[:5,11:]
# Out:
#    ExtractedTo                             ExtractedFrom         ExtractedCc  \
# Id
# 1          NaN  Sullivan, Jacob J <Sullivan11@state.gov>                 NaN
# 2          NaN                                       NaN                 NaN
# 3           B6       Mills, Cheryl D <MillsCD@state.gov>        Abedin, Huma
# 4          NaN       Mills, Cheryl D <MillsCD@state.gov>  Mitchell, Andrew B
# 5          NaN                                       NaN                 NaN
#
#                          ExtractedDateSent ExtractedCaseNumber  \
# Id
# 1   Wednesday, September 12, 2012 10:16 AM        F-2015-04841
# 2                                      NaN        F-2015-04841
# 3   Wednesday, September 12, 2012 11:52 AM        F-2015-04841
# 4    Wednesday, September 12,2012 12:44 PM        F-2015-04841
# 5                                      NaN        F-2015-04841
#
#    ExtractedDocNumber ExtractedDateReleased ExtractedReleaseInPartOrFull  \
# Id
# 1           C05739545            05/13/2015              RELEASE IN FULL
# 2           C05739546            05/13/2015              RELEASE IN PART
# 3           C05739547            05/14/2015              RELEASE IN PART
# 4           C05739550            05/13/2015              RELEASE IN PART
# 5           C05739554            05/13/2015              RELEASE IN PART
#
#                                     ExtractedBodyText  \
# Id
# 1                                                 NaN
# 2   B6\nThursday, March 3, 2011 9:45 PM\nH: Latest...
# 3                                                 Thx
# 4                                                 NaN
# 5   H <hrod17@clintonemail.com>\nFriday, March 11,...
#
#                                               RawText
# Id
# 1   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 2   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 3   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 4   UNCLASSIFIED\nU.S. Department of State\nCase N...
# 5   B6\nUNCLASSIFIED\nU.S. Department of State\nCa...

# %% [markdown]
# In addition to the `Emails.csv` that we have seen in the three exercises, we have three other files containing information about the senders and receivers.

# %%
persons = pd.read_csv('hillary-clinton-emails/Persons.csv')
persons.set_index(["Id"], drop=True, inplace=True)
print(len(persons))
persons.head(15)
# Out:
# 513
#                              Name
# Id
# 1                  111th Congress
# 2    AGNA USEMB Kabul Afghanistan
# 3                              AP
# 4                        ASUNCION
# 5                            Alec
# 6                      Alex Dupuy
# 7   American Beverage Association
# 8                   Andrew Mayock
# 9                  Andrew Shapiro
# 10           Anne-Marie Slaughter
# 11                   Anthony Lake
# 12              Arturo Valenzuela
# 13                    Ban Ki-moon
# 14                   Barack Obama
# 15               Barbara Mikulski

# %% [markdown]
# `Persons.csv` contains the names of all the people and organizations that are part of the email exchanges within this corpus. A unique `Id` is assigned for each person / organization.

# %%
aliases = pd.read_csv('hillary-clinton-emails/Aliases.csv')
aliases.set_index(["Id"], drop=True, inplace=True)
print(len(aliases))
len(aliases.PersonId.unique())
aliases.head(15)
# Out:
# 850
#                             Alias  PersonId
# Id
# 1                  111th congress         1
# 2    agna usemb kabul afghanistan         2
# 3                              ap         3
# 4                        asuncion         4
# 5                            alec         5
# 6                      dupuy alex         6
# 7   american beverage association         7
# 8                   mayock andrew         8
# 9                shapiro andrew j         9
# 10             shapiroa@state.gov         9
# 11             slaughter annmarie        10
# 12           slaughter anne marie        10
# 13            slaughter annemarie        10
# 14           slaughtera@state.gov        10
# 15                   lake anthony        11

# %% [markdown]
# `Aliases.csv` contains the different ways in which a person or organization from `Persons.csv` might appear in the email corpus. Using `unique()` we can validate that their are 513 unique `PersonId`s corresponding to the number of `Id`'s in `Persons.csv`.

# %%
receivers = pd.read_csv('hillary-clinton-emails/EmailReceivers.csv')
receivers.set_index(["Id"], drop=True, inplace=True)
print(len(receivers))
print(len(receivers.EmailId.unique()))
print(len(receivers.PersonId.unique()))
receivers.head(15)
# Out:
# 9306
# 7676
# 418
#     EmailId  PersonId
# Id
# 1         1        80
# 2         2        80
# 3         3       228
# 4         3        80
# 5         4        80
# 6         5        81
# 7         6       185
# 8         7        80
# 9         8        81
# 10        9        80
# 11       10        80
# 12       11        80
# 13       12        80
# 14       13        80
# 15       14        80

# %% [markdown]
# Out of the 7945 emails, `EmailReceivers.csv` has identified the receivers for 7676. This is great but unforunately we do not have such a table for the emails authors in order to build the graph. We'll have to extract this information from the `Emails.csv` file. From `Emails.csv`, we can use the columns `MetadataTo`, `MetadataFrom`, `ExtractedTo`, `ExtractedFrom`, and `ExtractedCc` to extract information for our graph.
#
# Just as a check, let's make sure than `PersonId` refers to Hillary since it seems to appear a lot in above preview.

# %%
persons.loc[80][0]
# Out:
# 'Hillary Clinton'

# %% [markdown]
# ### Extracting the nodes
#
# Our nodes will be the authors and recipients; we will extract them from the `MetadataTo`, `MetadataFrom`, `ExtractedTo`, `ExtractedFrom`, and `ExtractedCc` columns of `Emails.csv` and the other three files.
#
# Let's see how these fields are filled with data so that we can figure out how to parse the names.

# %%
nodes = []
for index, row in emails.iterrows():
    
    if index > 100: #print first 100 emails
        break
        
    print("EMAIL %d" % index)
    print("Receivers:")
    print(row.MetadataTo)
    print(row.ExtractedTo)
    recv = list(receivers[receivers.EmailId==index].PersonId)
    print([persons.loc[p][0] for p in recv])
    print()
    
    print("CC'ed:")
    print(row.ExtractedCc)
    print()
    
    print("Author")
    print(row.MetadataFrom)
    print(row.ExtractedFrom)
    print()
    
    print("---------------------------------")
# Out:
# EMAIL 1
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <Sullivan11@state.gov>
#
# ---------------------------------
# EMAIL 2
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# nan
#
# ---------------------------------
# EMAIL 3
# Receivers:
# ;H
# B6
# ['b6', 'Hillary Clinton']
#
# CC'ed:
# Abedin, Huma
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 4
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Mitchell, Andrew B
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 5
# Receivers:
# Abedin, Huma
# nan
# ['Huma Abedin']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 6
# Receivers:
# Russorv@state.gov
# nan
# ['Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 7
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 8
# Receivers:
# Abedin, Huma
# nan
# ['Huma Abedin']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 9
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <Sullivanli@stategov>
#
# ---------------------------------
# EMAIL 10
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# nan
#
# ---------------------------------
# EMAIL 11
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob 1 <Sullivan)) state.gov>
#
# ---------------------------------
# EMAIL 12
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# nan
#
# ---------------------------------
# EMAIL 13
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <SullivanJJ@state.gov>
#
# ---------------------------------
# EMAIL 14
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Slaughter, Anne-Marie
# nan
#
# ---------------------------------
# EMAIL 15
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# S_SpecialAssistants
#
# Author
# Mills, Cheryl D
# Mills, Cheryl 0 <MillsCD@state.gov›
#
# ---------------------------------
# EMAIL 16
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Koh, Harold Hongju
# Koh, Harold Hongju <KohliFf@state.gov>
#
# ---------------------------------
# EMAIL 17
# Receivers:
# H
# H; Mills, Cheryl D; Sullivan, Jacob J; Nuiand, Victoria J; Reines, Philippe
# ['Hillary Clinton', 'Cheryl Mills', 'nuiand victoria j', 'Philippe Reines', 'Jake Sullivan']
#
# CC'ed:
# Escrogirna, Ana A; Grantham, Chris W
#
# Author
# Sherman, Wendy R
# Sherman, Wendy R <ShermanWR@state.gov>
#
# ---------------------------------
# EMAIL 18
# Receivers:
# H
# H; Mills, Cheryl D; Sullivan, Jacob J, Nuland, Victoria 1; Reines, Philippe f
# ['Hillary Clinton', 'Cheryl Mills', 'reines philippe f', 'sullivan jacob j nuland victoria 1']
#
# CC'ed:
# Escrogima, Ana A
#
# Author
# Sherman, Wendy R
# Sherman, Wendy R <ShermanWR@state.gov>
#
# ---------------------------------
# EMAIL 19
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacobi <Sullivanii@state.gov>
#
# ---------------------------------
# EMAIL 20
# Receivers:
# Sherman, Wendy R
# nan
# ['Wendy Sherman']
#
# CC'ed:
# Escrogima, Ana A; Grantham, Chris W
#
# Author
# Sullivan, Jacob J
# nan
#
# ---------------------------------
# EMAIL 21
# Receivers:
# sullivanjj@state.gov
# nan
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 22
# Receivers:
# Russorv@state.gov
# nan
# ['Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 23
# Receivers:
# Russorv@state.gov
# 'Russorv@stategov'
# ['Robert Russo', 'russorv@stategov']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17©clintonemaiLcom>
#
# ---------------------------------
# EMAIL 24
# Receivers:
# sullivanjj@state.gov
# 'sullivanjj@state.gov'
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17@clintonemail.com>
#
# ---------------------------------
# EMAIL 25
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# McEldowney, Nancy E; Heffern, John A; Spence, Matthew 3.
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob .1 ‹Sullivann@state.gov>
#
# ---------------------------------
# EMAIL 26
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# nan
#
# ---------------------------------
# EMAIL 27
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob I <Sullivanit@state,gov›
#
# ---------------------------------
# EMAIL 28
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Macmanus, Joseph E (S[)ialAssistants; Abbaszadeh, Nima; Coleman, Claire L
#
# Author
# Mills, Cheryl D
# Mills, Cheryl 0 <MillsCD@stategov>
#
# ---------------------------------
# EMAIL 29
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Strider, Burns
# Burns Strider
#
# ---------------------------------
# EMAIL 30
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Sullivan, Jacob .1
#
# Author
# Abedin, Huma
# Abedin, Huma <AbedinH@state.goy>
#
# ---------------------------------
# EMAIL 31
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# McDonough, Denis R. (mailto: B6
#
# ---------------------------------
# EMAIL 32
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl 0 <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 33
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# nan
#
# ---------------------------------
# EMAIL 34
# Receivers:
# Russorv@state.gov
# 'Russorv@state.gov°
# ['Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17@clintonemail.com>
#
# ---------------------------------
# EMAIL 35
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Goldberger, Thomas H; Gardner, Rebecca V B6
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob .1 <Sullivarill@state.gov>
#
# ---------------------------------
# EMAIL 36
# Receivers:
# Mills, Cheryl D
# Mills, Cheryl D
# []
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 37
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Huma Abedin; Abedin, Huma; Hanley, Monica R; Valmoro, Lona i; Coleman, Claire
#
# Author
# Russo, Robert V
# Russo, Robert V <RussoRV©state.gov>
#
# ---------------------------------
# EMAIL 38
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 39
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Abedin, Huma
# Abeclin, Huma <AbedinH@state.gov>
#
# ---------------------------------
# EMAIL 40
# Receivers:
# H
# Marshall, Capricia P; Kennedy, Patrick F
# ['Hillary Clinton', 'Patrick Kennedy', 'Capricia Marshall']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# nan
#
# ---------------------------------
# EMAIL 41
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacobi <SullivanJJOstate.goy>
#
# ---------------------------------
# EMAIL 42
# Receivers:
# Mills, Cheryl D
# Mills, Cheryl D; Kennedy, Patrick F
# ['Patrick Kennedy', 'Cheryl Mills']
#
# CC'ed:
# nan
#
# Author
# Marshall, Capricia P
# Mills, Cheryl D
#
# ---------------------------------
# EMAIL 43
# Receivers:
# Flores, Oscar
# Oscar Flores
# ['Oscar Flores', 'oscar flores']
#
# CC'ed:
# nan
#
# Author
# H
# H < hrod17@clintonemail.com>-
#
# ---------------------------------
# EMAIL 44
# Receivers:
# sullivanjj@state.gov
# 'sullivanjj@state.gov`
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17@dintonemailcom>
#
# ---------------------------------
# EMAIL 45
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Milts, Cheryl 0 <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 46
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacobi <Sullivaniiestate.gov>
#
# ---------------------------------
# EMAIL 47
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# Sidney Blumenthal
#
# ---------------------------------
# EMAIL 48
# Receivers:
# sullivanjj@state.gov
# 'sullivanjj@state.gov'
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17@clintonemail.com>
#
# ---------------------------------
# EMAIL 49
# Receivers:
# sullivanjj@state.gov
# 'su II iva gll@state.gov.
# ['su ii iva gll@state.gov.', 'Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H < hrod17@clintonemail.com>
#
# ---------------------------------
# EMAIL 50
# Receivers:
# Mills, Cheryl D
# Mills, Cheryl 0; Kennedy, Patrick F
# ['Patrick Kennedy', 'Cheryl Mills', 'Cheryl Mills']
#
# CC'ed:
# nan
#
# Author
# Marshall, Capricia P
# Marshall, Capricia P <MarshalICP@state.gov>
#
# ---------------------------------
# EMAIL 51
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# nan
#
# ---------------------------------
# EMAIL 52
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Abedin, Huma
#
# Author
# Slaughter, Anne-Marie
# Anne-Marie Slaughter
#
# ---------------------------------
# EMAIL 53
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# Sidney Blumenthal
#
# ---------------------------------
# EMAIL 54
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# nan
#
# ---------------------------------
# EMAIL 55
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Burns, William J
# Burns, William J <BurnsW.1@state.gov>
#
# ---------------------------------
# EMAIL 56
# Receivers:
# sullivanjj@state.gov
# 'sullivahu@state.gov'
# ['sullivahu@state.gov', 'Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17@clintonernail.com>
#
# ---------------------------------
# EMAIL 57
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Barton, Rick (CSO)
#
# ---------------------------------
# EMAIL 58
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <Sullivann@state.gov>
#
# ---------------------------------
# EMAIL 59
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <SullivanDostate.gov>
#
# ---------------------------------
# EMAIL 60
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl ID <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 61
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Slaughter, Anne-Marie
# nan
#
# ---------------------------------
# EMAIL 62
# Receivers:
# Russorv@state.gov
# nan
# ['Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 63
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 64
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Miller, James N; Blair, Oni K; Lakhdhir, Kamala S; Austin-Ferguson, Kathleen T; Lohman, Lee
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <Sullivann@state.gov>
#
# ---------------------------------
# EMAIL 65
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl ID <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 66
# Receivers:
# sullivanjj@state.gov
# 'sullivanjj@state.gov'
# ['Jake Sullivan']
#
# CC'ed:
# Huma Abedin
#
# Author
# H
# H <hrod17@clintonemailcom>
#
# ---------------------------------
# EMAIL 67
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Huma Abedin
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob J <Sullivanii@stategov>
#
# ---------------------------------
# EMAIL 68
# Receivers:
# Russorv@state.gov
# nan
# ['Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 69
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Boswell, Eric J
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacobi <SullivanJJ state.gov>
#
# ---------------------------------
# EMAIL 70
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# Sidney Blumenthal
#
# ---------------------------------
# EMAIL 71
# Receivers:
# Russorv@state.gov
# Russoiv@state.gov'
# ['russoiv@state.gov', 'Robert Russo']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrodl7@clintonemaii.com›
#
# ---------------------------------
# EMAIL 72
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Huma Abedin
#
# Author
# Hanley, Monica R
# Hanley, Monica R <HanleyMR@state.gov>
#
# ---------------------------------
# EMAIL 73
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 74
# Receivers:
# sullivanjj@state.gov
# 'sullivanjj@state.gov'
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17©clintonemailcom>
#
# ---------------------------------
# EMAIL 75
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Mills, Cheryl D
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 76
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Kalmbach, Heather E; Keene, Matt E
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob <Sullivanil@state.gov›
#
# ---------------------------------
# EMAIL 77
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Blumenthal, Sidney
# Sidney Blumenthal
#
# ---------------------------------
# EMAIL 78
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Sullivan, Jacob J
# nan
#
# ---------------------------------
# EMAIL 79
# Receivers:
# abedinh@state.gov
# 'abedinh@state.gov
# ['Huma Abedin']
#
# CC'ed:
# nan
#
# Author
# H
# H <hrod17©clintonemail.com>
#
# ---------------------------------
# EMAIL 80
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Reines, Philippe I; Mills, Cheryl D; Adams, David S
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 81
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# nan
#
# ---------------------------------
# EMAIL 82
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# nan
# B6
#
# ---------------------------------
# EMAIL 83
# Receivers:
# millscd@state.gov
# 'miliscd@stategov"
# ['miliscd@stategov', 'Cheryl Mills']
#
# CC'ed:
# Reines, Philippe 1; Mills, Cheryl D; Adams, David S
#
# Author
# H
# H <hrod17@clintonemail.com>
#
# ---------------------------------
# EMAIL 84
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov›
#
# ---------------------------------
# EMAIL 85
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Mills, Cheryl D
# Mills, Cheryl D <MillsCD@state.gov>
#
# ---------------------------------
# EMAIL 86
# Receivers:
# sullivanjj@state.gov
# nan
# ['Jake Sullivan']
#
# CC'ed:
# nan
#
# Author
# H
# nan
#
# ---------------------------------
# EMAIL 87
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Sullivan, Jacob J; Abedin, Hurna; Hanley, Monica R
#
# Author
# Schwerin, Daniel B
# Schwerin, Daniel B <SchwerinDB@state.gov>
#
# ---------------------------------
# EMAIL 88
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Hume Abedin
#
# Author
# Hanley, Monica R
# Hanley, Monica R <HanleyMR@state.gov>
#
# ---------------------------------
# EMAIL 89
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Sullivan, Jacob 3; Abedin, Huma; Hanley, Monica R
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacob 3 <Sullivanii@state.gov>
#
# ---------------------------------
# EMAIL 90
# Receivers:
# hanleymr@state.gov
# 'hanleymr@state.gov'
# ['Monica Hanley']
#
# CC'ed:
# Huma Abedin
#
# Author
# H
# H <hrod17©clintonemail.com>
#
# ---------------------------------
# EMAIL 91
# Receivers:
# Schwerin, Daniel B
# Schwerin, Daniel B; H
# ['Hillary Clinton', 'Daniel Schwerin']
#
# CC'ed:
# Sullivan, Jacob J; Abedin, Huma
#
# Author
# Hanley, Monica R
# Hanley, Monica R <HanleyMR@state.gov>
#
# ---------------------------------
# EMAIL 92
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Abedin, Huma
# Abedin, Huma <AbedinH@state.gov>
#
# ---------------------------------
# EMAIL 93
# Receivers:
# hanleymr@state.gov
# H
# ['Monica Hanley']
#
# CC'ed:
# Huma Abedin
#
# Author
# H
# H <hrod17@clintonernail.com>
#
# ---------------------------------
# EMAIL 94
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Sullivan, Jacob 3; Abedin, Hume; Hanley, Monica R
#
# Author
# Sullivan, Jacob J
# Sullivan, Jacobi <Suilivanll@state.gov>
#
# ---------------------------------
# EMAIL 95
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Abedin, Huma
# Abedin, Huma <AbedinH@state.gov>
#
# ---------------------------------
# EMAIL 96
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Burns, William 3; Welk, Alice G; Sanderson, Janet A
#
# Author
# Abedin, Huma
# Abedin, Hume <AbeclinH@stategov›
#
# ---------------------------------
# EMAIL 97
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Huma Abedin
#
# Author
# Hanley, Monica R
# Hanky, Monica R <HanleyMR@stategov>
#
# ---------------------------------
# EMAIL 98
# Receivers:
# Nides, Thomas R
# Nides, Thomas R; H
# ['Hillary Clinton', 'Thomas Nides']
#
# CC'ed:
# Adler Caroline E
#
# Author
# Reines, Philippe I
# Reines, Philippe I < reinesp@state.gove
#
# ---------------------------------
# EMAIL 99
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# Huma Abedin
#
# Author
# Hanley, Monica R
# Hanley, Monica R <HanleyMR@state.gov>
#
# ---------------------------------
# EMAIL 100
# Receivers:
# H
# nan
# ['Hillary Clinton']
#
# CC'ed:
# nan
#
# Author
# Abedin, Huma
# Abedin, Hume <AbedinH©state_gov>
#
# ---------------------------------

# %% [markdown]
# Some observations:
#
# * `MetadataFrom` seems more dependable for extracting the author (`H` seems to be an alternative form of refering to Hillary Clinton)
# * `ExtractedCc` can be used to obtain additional people in the email conversation
# * `EmailReceivers.csv` seems to be the most useful resource to obtain the receivers (also with its entries we have a usefull way of mapping emails / aliases to the full name)
#
# So from these "resources" will create a DataFrame with three columns, where each row will represent an edge in our graph. The columns will be:
#
# 1. EmailId : corresponding to the `Id` of `Emails.csv`
# 2. Author : obtained from `MetadataFrom` of `Emails.csv`
# 3. Receiver : one of the receivers from `EmailReceivers.csv` and `ExtractedCc`
#
# The nodes will be Author and Receiver.

# %%
columns = ['EmailId','Author', 'Receiver']
df_graph = pd.DataFrame(columns=columns)
num_entries = 0

for email_id, row in emails.iterrows():
    
    if index > 100: #print first 100 emails
        break
        
    author = row.MetadataFrom
    recv = list(receivers[receivers.EmailId==index].PersonId)
    print([persons.loc[p][0] for p in recv])
# Out:
# Empty DataFrame
# Columns: [EmailId, Author, Receiver]
# Index: []

# %%
df_graph.loc[0] = [randint(-1,1) for n in range(3)]
df_graph
# Out:
#    EmailId  Author  Receiver
# 0     -1.0     0.0       0.0
