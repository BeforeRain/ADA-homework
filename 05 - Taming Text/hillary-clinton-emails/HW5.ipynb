# %% [markdown]
# # Homework 05 - Taming Text
#
# ## Data description & preparation

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
email = pd.read_csv('Emails.csv')

# %%
email.isnull().any()
email.shape
# Out:
# (7945, 22)

# %%
email1=email.dropna(axis=0)
email1.shape
# Out:
# (908, 22)

# %%
email2 = email.to_string()

# %%
email3 = email1.to_string()

# %% [markdown]
# ## Task 1: Generate a word cloud based on the raw corpus. Implement a standard text pre-processing pipeline (e.g., tokenization, stopword removal, stemming, etc.) and generate a new word cloud. Discuss briefly the pros and cons (if any) of the two word clouds you generated.
#
# ### Generate a word cloud based on the raw corpus.

# %%
from wordcloud import WordCloud
from os import path
import csv

# %%
d = path.dirname('E:/2016-2017fall/ada/Homework_sissy/05 - Taming Text/hillary-clinton-emails/')

# Read the whole text.
text = open(path.join(d, 'Emails.csv')).read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-15-f4e215a2c384> in <module>()
#       2
#       3 # Read the whole text.
# ----> 4 text = open(path.join(d, 'Emails.csv')).read()
#
# D:\anaconda\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 15404343: character maps to <undefined>

# %%
# Generate a word cloud image
wordcloud = WordCloud().generate(email2)

plt.imshow(wordcloud)
plt.axis("off")
plt.show()
